# %%
import numpy as np
import random as r
alph = "qwertyuiopasdfghjklzxcvbnm"
cap = "QWERTYUIOPASDFGHJKLZXCVBNM"
# alph = [0,1]
dig = "1234567890"
spac = "   "*8
alph = alph+dig+cap
ln = 10**4*6
lm = 10**4*4
# alpl = 2
# alph = alph[:alpl] + dig[:alpl]
# lm = 10000
v = 10**4
row = 100
col = 11
v = 16
v = 10**4
ln = 10**1
lm = 10000
alpl = 2
# alpl = len(alph)
# n = 2300*3
n = 1
k = v**2
for j in range(1):
    m = r.randint(1,lm)
    n = r.randint(2,ln)
    n = 1
    # m = r.randint(0,lm*100)
    # n2 = r.randint(1,lm)
    # n3 = r.randint(1,lm)
    # n = n2+n3
    # # rt = r.randint(l,10000)
    # print('[',end='')
    # # alpl = r.randint(2,8)
    # # alpl = 5
    # for i in range(n-1):
    #     print('['+','.join([str(x) for x in (np.random.randint(-v,v,i+1))]),end='],')
        # print('"'+''.join([str(r.choice(alph[:alpl])) for i in range(r.randint(1,lm))])+'"',end=',')
        # print('['+','.join(['"'+str(r.choice(alph[:alpl]))+'"' for i in range(m)])+'],',end='')
    # print('['+','.join([str(x) for x in (np.random.randint(-v,v,n))])+']]')
    # print('"'+''.join([str(r.choice(alph[:alpl])) for i in range(r.randint(1,lm))])+'"]')
    # print('['+','.join(['"'+str(r.choice(alph[:alpl]))+'"' for i in range(m)])+']]')
    # print(']')
    # print('"'+''.join([str(r.choice(alph[:alpl])) for i in range(n)])+'"')
    # print('"'+''.join(r.choice(alph[:alpl+0]) for x in range(r.randint(1,n)))+'"')
    # print('"'+''.join(r.choice(alph[:alpl+0]) for x in range(r.randint(0,m)))+'"')
    # ===================================================
    # ll = ''.join(str(i) for i in np.random.choice([0,1],n))
    # print('"'+"0"+ll[1:]+'"')
    # ===================================================
    # menu with values
    print('["Solution"'+',"getRandom"'*m+']')
    ll = list(np.random.randint(-v,v,n))
    print('[',[ll],',[]'*m+']')
    # print('['+','.join(['"'+str(r.choice(alph[:alpl]))+'"' for i in range(m)])+']]')
    
    # ===================================================
    # ll = list(range(min(v,n)))*(n//3+1)
    # r.shuffle(ll)
    # ll[r.randint(0,n-1)] = 0
    # print(ll[:n])
    # ll = list(np.random.randint(1,10,13))
    # ll = sorted(set(ll))
    # ll = ll[:n]
    # print('['+','.join(['"'+str(i)+'"' for i in ll])+']')
    # m = (r.randint(1,n-1))
    # print(n)
    # print(r.randint(1,lm))
    # print(r.randint(2,lm))
    # ===================================================
    # f = set(np.random.randint(1,v//2,n))
    # ll = []
    # for _ in range(n):
    #     l = r.randint(1,v)
    #     ll.append([l,r.randint(l,v)])
    # print(ll)
    # el = 1
    # for i in f:
    #     if len(ll)+i <= lm:
    #         ll.extend([el]*i)
    #         el += 1
    #     else:
    #         break
    # if not ll:
    #     continue
    # r.shuffle(ll)
    
    # ===================================================""
    # print('["StockSpanner"'+',"next"'*(n-1)+']\n[[]',end='')
    # print(''.join([',['+str(x)+']' for x in np.random.randint(1,v,n-1)])+']')

    # ===================================================
    # p = 10
    # d = 10
    # c = 10
    # ll = []
    # for i in range(n):
    #     t = r.randint(1,p)
    #     l = r.randint(0,d-1)
    #     h = r.randint(l+1,d)
    #     ll.append([t,l,h])
    # print(ll)
    # print(r.randint(1,c))
    # ll = list(list(np.random.choice([0,0,0,0,0,0,0,1,2],m)) for i in range(n))

    # d = list("+-*/")
    # print('"'+str(ll[-1]),end='')
    # for i in ll[:-1]:
    #     if i:
    #         print(r.choice(d)+str(i),end='')
    #     else:
    #         print(r.choice(d[:-1])+str(i),end='')
    # print('"')
    #     co = set(np.random.randint(1,col,r.randint(1,10)))
    #     l.extend(list([v,c] for c in co))
    # r.shuffle(l)
    # print(ll)
    # print(r.randint(0,n-1))
    # print(r.randint(0,m-1))
    # print(r.randint(1,v))
    # print(j)

    # print('['+','.join(['['+str(ri)+','+str(ci)+']' for ri,ci in ll])+']')

    # print(''.join(list(str(x) for x in np.random.randint(0,2,ln))))
    # ===================================================
    # print(']')
    # ll = []
    # while len(ll) < 2:
    # ll = (list(set(np.random.randint(-v,v,n))))
    # ll = list(np.random.randint(0,v+1,n))
    # for i in range(n//2+1,n):
    #     ll[i] = r.choice(["null",ll[i]])
    # print(ll)
    # print('['+','.join(['['+str(ll[i-1])+','+str(ll[i])+']' for i in range(1,len(ll),2)])+']')
    # ll = sorted(list(set(np.random.randint(0,v,n))))
    # print('['+','.join(['['+str(ll[i-1])+','+str(ll[i])+']' for i in range(1,len(ll),2)])+']')
    # print(m-n)
    # ll = list(x for x in range(0,n+1) for j in range(2))
    # ll.remove(r.randint(1,n))
    # # r.shuffle(ll)
    # # ll = (list(np.random.randint(-v,v,n)))
    # print('['+','.join([str(x) for x in (ll)])+']')
    # print(n)

    # for i in range(l//2,l):
    #     if r.choice([0,0,1]):
    #         ll[i] = 'null'
    # k = r.randint(0,l)
    # ll = sorted((np.random.randint(-v,v,n)))
    # print(ll)
    # print('['+','.join([str(x) for x in ll])+']')
    # print('['+','.join([str(x) for x in ll[:k]+ll[k:]])+']')
    # print('['+','.join([str(x) for x in np.random.randint(-v,v,n)])+']')
    # print('['+','.join([str(x) for x in np.random.randint(-v,v,n)])+']')
    # print('['+','.join([str(x)+'0' for x in np.random.randint(1,v,n)])+']')
    # print('['+','.join([str(x) for x in sorted((np.random.randint(-v,v,n)))])+']')
    # print('['+','.join([str(x) for x in np.random.randint(1,v,n)])+']')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(n2))+'"')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(n3))+'"')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(m))+'"')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(n))+'"')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(r.randint(1,l)))+'"')
    # print('"'+str(r.randint(0,l))+'"')
    # print('"'+str(r.randint(0,l))+'"')
    # print(r.randint(-v-v//5,v+v//5))
    # a = (r.randint(2,lm))
    # b = r.randint((a+1)//2,a*2)
    # print(r.randint(1,n))
    # t = (r.randint(2,v))
    # print(m)
    # print(n)
    # print(r.randint(2**t-2,2**t+2))
    # print(j)
    # print(sum(np.random.choice(ll,2)))
    # print(a)
# Out:
# ["Solution","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","getRandom","get ...
# [ [[92]] ,[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[],[], ...

# %%
#importing libraries
import cv2
import numpy as np

#reading image
img = cv2.imread("catimg.jpg")

# Edges
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur (gray, 5)
edges = cv2.adaptiveThreshold (gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 9, 9)

#Cartoonization
color = cv2.bilateralFilter(img, 9, 250, 250)
cartoon = cv2.bitwise_and(color, color, mask=edges)

cv2.imshow("Image", img)
cv2.imshow("edges", edges)
cv2.imshow("cartoon", cartoon)
# cv2.waitkey (0)
# cv2.destroyAllWindows()
