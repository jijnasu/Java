# %%
import numpy as np
import random as r
alph = "01qwertyuiopasdfghjklzxcvbnm"
# alph = "QWERTYUIOPASDFGHJKLZXCVBNM"
# alph = "()"
dig = "1234567890"
ln = 10**4*5
# lm = 10**1#2*2
# alpl = 2
# alph = alph[:alpl] + dig[:alpl]
# lm = 10000
v = 10**3
row = 10**1
col = 11
# ln = 30
# v = 10**1
k = v**2
for j in range(1):
    # m = r.randint(0,lm)
    n = r.randint(1,ln)
    # m = r.randint(0,lm*100)
    # n2 = r.randint(1,lm)
    # n3 = r.randint(1,lm)
    # n = n2+n3
    # # rt = r.randint(l,10000)
    # print('[',end='')
    # # alpl = r.randint(2,8)
    # # alpl = 5
    # for i in range(n-1):
    #     print('['+','.join([str(x) for x in set(np.random.randint(i+1,n,r.randint(0,n-1-i)))]),end='],')
    # #     # print('"'+''.join([str(r.choice(alph[:alpl])) for i in range(r.randint(0,lm))])+'"',end=',')
        # print('['+','.join(['"'+str(r.choice(alph[:alpl]))+'"' for i in range(m)])+'],',end='')
    # # print('"'+''.join([str(r.choice(alph[:alpl])) for i in range(r.randint(0,lm))])+'"]')
    # print('['+','.join(['"'+str(r.choice(alph[:alpl]))+'"' for i in range(m)])+']]')
    # print(']')
    # print('"'+''.join([str(r.choice(alph[:])) for i in range(n)])+'"')
    # print('"'+''.join(r.choice(alph[:alpl+0]) for x in range(r.randint(1,n)))+'"')
    # print('"'+''.join(r.choice(alph[:alpl+0]) for x in range(r.randint(0,m)))+'"')
    # ===================================================
    ll = list(range(min(v,n)))*(n//3+1)
    r.shuffle(ll)
    ll[r.randint(0,n-1)] = 0
    print(ll[:n])
    print(r.randint(0,n-1))
    # ===================================================
    # f = set(np.random.randint(1,v//2,n))
    # ll = []
    # el = 1
    # for i in f:
    #     if len(ll)+i <= lm:
    #         ll.extend([el]*i)
    #         el += 1
    #     else:
    #         break
    # if not ll:
    #     continue
    # r.shuffle(ll)
    # ===================================================""
    # print('["StockSpanner"'+',"next"'*(n-1)+']\n[[]',end='')
    # print(''.join([',['+str(x)+']' for x in np.random.randint(1,v,n-1)])+']')

    # ===================================================
    # ll = list(np.random.randint(1,n+1,min(n,10**3)))
    # l = []
    # for i,v in enumerate(set(ll)):
    #     co = set(np.random.randint(1,col,r.randint(1,10)))
    #     l.extend(list([v,c] for c in co))
    # r.shuffle(l)
    # print(n)
    # print('['+','.join(['['+str(ri)+','+str(ci)+']' for ri,ci in l])+']')


    # ===================================================
    # print(']')
    # ll = []
    # while len(ll) < 2:
    # ll = (list(set(np.random.randint(0,v,n))))
    # ll = set(np.random.randint(1,v,n))
    # print(ll)
    # print('['+','.join(['['+str(ll[i-1])+','+str(ll[i])+']' for i in range(1,len(ll),2)])+']')
    # ll = sorted(list(set(np.random.randint(0,v,n))))
    # print('['+','.join(['['+str(ll[i-1])+','+str(ll[i])+']' for i in range(1,len(ll),2)])+']')
    # print(m-n)
    # ll = list(x for x in range(0,n+1) for j in range(2))
    # ll.remove(r.randint(1,n))
    # # r.shuffle(ll)
    # # ll = (list(np.random.randint(-v,v,n)))
    # print('['+','.join([str(x) for x in (ll)])+']')
    # print(n)

    # for i in range(l//2,l):
    #     if r.choice([0,0,1]):
    #         ll[i] = 'null'
    # k = r.randint(0,l)
    # print('['+','.join([str(x) for x in ll[:k]+ll[k:]])+']')
    # print('['+','.join([str(x) for x in np.random.randint(-v,v,n)])+']')
    # print('['+','.join([str(x) for x in np.random.randint(-v,v,n)])+']')
    # print('['+','.join([str(x) for x in np.random.randint(-v,v,n)])+']')
    # print('['+','.join([str(x) for x in np.random.randint(-v,v,n)])+']')
    # print('['+','.join([str(x) for x in np.random.randint(0,v,n)])+']')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(n2))+'"')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(n3))+'"')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(n))+'"')
    # print('"'+''.join(r.choice(alph[:alpl]) for x in range(r.randint(1,l)))+'"')
    # print('"'+str(r.randint(0,l))+'"')
    # print('"'+str(r.randint(0,l))+'"')
    # print(r.randint(-v-v//5,v+v//5))
    # a = (r.randint(2,lm))
    # b = r.randint((a+1)//2,a*2)
    # print(r.randint(1,el-1))
    # print(r.randint(0,n-1))
    # print(n)
    # print(r.randint(1,n))
    # print(a)
# Out:
# [99, 748, 786, 601, 390, 13, 325, 358, 133, 552, 498, 247, 528, 412, 653, 42, 669, 999, 921, 887, 663, 363, 280, 609, 435, 403, 724, 578, 32, 427, 407, 718, 9, 278, 89, 811, 582, 246, 957, 300, 666, 441, 703, 224, 95, 350, 321, 614, 483, 391, 564, 902, 988, 557, 181, 355, 342, 62, 933, 966, 710, 37, 531, 8, 112, 713, 297, 194, 294, 725, 520, 205, 926, 603, 850, 925, 826, 803, 633, 579, 507, 13, 191, 856, 791, 801, 973, 374, 95, 383, 304, 645, 892, 80, 382, 393, 93, 715, 176, 493, 810, 975, 346, 447, 826, 371, 833, 185, 312, 460, 755, 495, 327, 121, 866, 262, 786, 127, 609, 583, 437, 757, 854, 205, 534, 666, 744, 455, 82, 603, 718, 249, 874, 321, 648, 234, 676, 602, 88, 429, 535, 977, 290, 898, 882, 487, 501, 117, 722, 958, 604, 896, 307, 186, 219, 143, 833, 845, 792, 353, 85, 599, 444, 567, 549, 892, 357, 608, 891, 277, 624, 252, 722, 312, 652, 674, 766, 93, 374, 885, 934, 196, 373, 983, 289, 346, 890, 247, 667, 261, 348, 806, 418, 486, 806, 793, 298, 249, 696, 133, 167, 988, 934, 24
# ...

# %%
#importing libraries
import cv2
import numpy as np

#reading image
img = cv2.imread("catimg.jpg")

# Edges
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur (gray, 5)
edges = cv2.adaptiveThreshold (gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 9, 9)

#Cartoonization
color = cv2.bilateralFilter(img, 9, 250, 250)
cartoon = cv2.bitwise_and(color, color, mask=edges)

cv2.imshow("Image", img)
cv2.imshow("edges", edges)
cv2.imshow("cartoon", cartoon)
# cv2.waitkey (0)
# cv2.destroyAllWindows()
